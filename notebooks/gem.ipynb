# %%
from config import DEFAULT_GEF_PATH, PROCESSED_DATA_DIR
from data_processing import process_gef_bins

# ============================
# 1. 基础设置与数据加载
# ============================
gef_path = str(DEFAULT_GEF_PATH)
output_dir = PROCESSED_DATA_DIR

# 处理多个 bin size（50/100/150）
process_gef_bins(
    gef_path=gef_path,
    bin_sizes=[50, 100, 150],
    output_dir=output_dir,
    min_gene=10,
    rotate=True,
)
